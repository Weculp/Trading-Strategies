# %% [markdown]
# # 06 — Results and Visuals
#
# Calls into `src.generate_plots` to produce the static PNGs, animated GIF, and interactive plotly HTML used in the README and paper.

# %% [markdown]
# ## 1. Generate everything

# %%
# !python -m src.generate_plots

# %% [markdown]
# ## 2. Display the hero chart inline

# %%
from IPython.display import Image, HTML
Image('../plots/01_cumulative_pnl_hero.png')

# %% [markdown]
# ## 3. Display the year-by-year

# %%
Image('../plots/02_yearly_breakdown.png')

# %% [markdown]
# ## 4. Drawdown

# %%
Image('../plots/03_drawdown_underwater.png')

# %% [markdown]
# ## 5. Sharpe progression

# %%
Image('../plots/04_sharpe_progression.png')

# %% [markdown]
# ## 6. Threshold sensitivity

# %%
Image('../plots/06_threshold_sensitivity.png')

# %% [markdown]
# ## 7. Out-of-sample holdout

# %%
Image('../plots/07_oos_holdout.png')

# %% [markdown]
# ## 8. Animated equity curve (preview)

# %%
from IPython.display import HTML
HTML('<img src="../plots/cumulative_pnl_animated.gif">')

# %% [markdown]
# ## 9. Interactive plotly chart

# %%
from IPython.display import IFrame
IFrame('../plots/interactive/cumulative_pnl.html', 1100, 580)
